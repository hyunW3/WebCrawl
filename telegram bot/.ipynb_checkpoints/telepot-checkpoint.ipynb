# %%
#https://telepot.readthedocs.io/en/latest/
# [송유석 형 14반도체] [오후 10:18] 싸이킷런이나 케라스나  텐서플로 함 써보셈

#test the account
import telepot
token = "704098129:AAFzYmlGwAqr87KIJDrIonLX_K4mvmA_Bag"
bot = telepot.Bot(token)
bot.getMe()
# Out:
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\telepot\loop.py", line 60, in run_forever
#     allowed_updates=allowed_updates)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\telepot\__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\telepot\__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\telepot\api.py", line 155, in request
#     return _parse(r)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\telepot\api.py", line 147, in _parse
#     raise e(description, error_code, data)
# telepot.exception.UnauthorizedError: ('Unauthorized', 401, {'ok': False, 'error_code': 401, 'description': 'Unauthorized'})
# Traceback (most recent call last):
# ...

# %%
#Receive messages
from pprint import pprint
response = bot.getUpdates() # response as python dictionary
pprint(response)
# Out:
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\telepot\loop.py", line 60, in run_forever
#     allowed_updates=allowed_updates)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\telepot\__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\telepot\__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\telepot\api.py", line 155, in request
#     return _parse(r)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\telepot\api.py", line 147, in _parse
#     raise e(description, error_code, data)
# telepot.exception.UnauthorizedError: ('Unauthorized', 401, {'ok': False, 'error_code': 401, 'description': 'Unauthorized'})
# Traceback (most recent call last):
# ...

# %%
#An easier way to receive messages 
from telepot.loop import MessageLoop
def handle(msg):
    pprint(msg)
MessageLoop(bot, handle).run_as_thread()
# Out:
# {'chat': {'first_name': 'HyunWoong',
#           'id': 362927551,
#           'last_name': 'Bae',
#           'type': 'private',
#           'username': 'hwbae0326'},
#  'date': 1551617724,
#  'from': {'first_name': 'HyunWoong',
#           'id': 362927551,
#           'is_bot': False,
#           'language_code': 'ko',
#           'last_name': 'Bae',
#           'username': 'hwbae0326'},
#  'message_id': 5,
#  'text': 'hi'}
# {'chat': {'first_name': 'HyunWoong',
#           'id': 362927551,
#           'last_name': 'Bae',
#           'type': 'private',
#           'username': 'hwbae0326'},
#  'date': 1551617726,
#  'from': {'first_name': 'HyunWoong',
#           'id': 362927551,
#           'is_bot': False,
#           'language_code': 'ko',
#           'last_name': 'Bae',
#           'username': 'hwbae0326'},
#  'message_id': 6,
#  'text': 'hi there'}
# {'chat': {'first_name': 'HyunWoong',
#           'id': 362927551,
#           'last_name': 'Bae',
#           'type': 'private',
# ...

# %%
bot.sendMessage(362927551,"그거 인정")
# Out:
# {'message_id': 9,
#  'from': {'id': 735912252,
#   'is_bot': True,
#   'first_name': 'SkkuSemiNoticeBot',
#   'username': 'SkkuSemiNoticeBot'},
#  'chat': {'id': 362927551,
#   'first_name': 'HyunWoong',
#   'last_name': 'Bae',
#   'username': 'hwbae0326',
#   'type': 'private'},
#  'date': 1551618077,
#  'text': '그거 인정'}

# %%
#Quickly glance a message
import sys
import time
import telepot
from telepot.loop import MessageLoop

def handle(msg):
    content_type, chat_type, chat_id = telepot.glance(msg)
    print(content_type, chat_type, chat_id)
    
    if content_type == 'text':
        bot.sendMessage(chat_id,mesg['text'])
#TOKEN = sys.argv[1] # get token from command-Line
token = "735912252:AAEM8UAZyLYdQaAY58dyHVjN9D5H3hs40CI"

bot = telepot.Bot(token)
MessageLoop(bot, handle).run_as_thread()
print('Listening ...')

#Keep the program running.
# Out:
# Listening ...
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\telepot\loop.py", line 60, in run_forever
#     allowed_updates=allowed_updates)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\telepot\__init__.py", line 1000, in getUpdates
#     return self._api_request('getUpdates', _rectify(p))
#   File "C:\ProgramData\Anaconda3\lib\site-packages\telepot\__init__.py", line 491, in _api_request
#     return api.request((self._token, method, params, files), **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\telepot\api.py", line 155, in request
#     return _parse(r)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\telepot\api.py", line 150, in _parse
#     raise exception.TelegramError(description, error_code, data)
# telepot.exception.TelegramError: ('Not Found', 404, {'ok': False, 'error_code': 404, 'description': 'Not Found'})
# Traceback (most recent call last):
# ...
